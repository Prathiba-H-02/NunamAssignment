# %%
import pandas as pd

# %%
df=pd.read_csv('detailVolDownSampled.csv')

# %%
df
# Out:
#                  Realtime  Unnamed: 0  Record ID  Step Name  \
# 0     2020-10-10 20:03:00        11.0       12.0   1.347826
# 1     2020-10-10 20:04:00        52.5       53.5   1.000000
# 2     2020-10-10 20:05:00       112.5      113.5   1.000000
# 3     2020-10-10 20:06:00       172.5      173.5   1.000000
# 4     2020-10-10 20:07:00       232.5      233.5   1.000000
# ...                   ...         ...        ...        ...
# 6939  2020-10-16 03:21:00     23220.5   458384.5   2.000000
# 6940  2020-10-16 03:22:00     23280.5   458444.5   2.000000
# 6941  2020-10-16 03:23:00     23340.5   458504.5   2.000000
# 6942  2020-10-16 03:24:00     23400.5   458564.5   2.000000
# 6943  2020-10-16 03:25:00     23450.5   458614.5   2.000000
#
#       Auxiliary channel TU1 U(V)  Gap of Voltage
# 0                      -0.001296             0.0
# 1                      -0.001270             0.0
# 2                      -0.001282             0.0
# ...

# %%
# sample period - 60s
# sample freq- 416681/60s=6944.68 Hz
# total - 25000860 (period* freq)
# 1/60 - 0.0166 Hz
#cutoff- 1.5

# %%
len(df)
# Out:
# 6944

# %%
import numpy as np
from scipy.signal import butter,filtfilt
# Filter requirements.
T = 60.0        # Sample Period
fs = 6944       # sample rate, Hz
cutoff = 1.5     # desired cutoff frequency of the filter, Hz ,      slightly higher than actual 1.2 Hz
nyq = 0.5 * fs  # Nyquist Frequency
n = len(df)
order=2

# %%
def butter_lowpass_filter(data, cutoff, fs, order):
    normal = cutoff / nyq 
    b, a = butter(order, normal, btype='low', analog=False)
    y = filtfilt(b, a, data)
    return y

# %%
out=butter_lowpass_filter(df['Unnamed: 0'],cutoff,fs,order)

# %%
import plotly.graph_objs as go

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
            out = df['Unnamed: 0'],
            line =  dict(shape =  'spline' ),
            ))
fig.add_trace(go.Scatter(
            out = out,
            line =  dict(shape =  'spline' ),
            name = 'filtered signal'
            ))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-d322ff770eaa> in <module>
#       1 fig = go.Figure()
# ----> 2 fig.add_trace(go.Scatter(
#       3             out = df['Unnamed: 0'],
#       4             line =  dict(shape =  'spline' ),
#       5             ))
#
# ...

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
df1 = df.head(25)
df1.plot(kind='bar',figsize=(16,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
